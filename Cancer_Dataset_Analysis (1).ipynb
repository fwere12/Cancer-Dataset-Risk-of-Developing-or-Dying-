# %%
#Importing the necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#reading in the dataset
df = pd.read_csv("/content/Risk of Developing or Dying From Cancer.csv")
df.head(5)
# Out:
#                 Cancer Type  Male Risk Development Percentage  \
# 0                Any cancer                              41.6
# 1                   Bladder                               3.6
# 2  Brain and nervous system                               0.7
# 3                    Breast                               0.1
# 4          Colon and rectum                               4.3
#
#    Male Risk Development Ratio(One in ____ Person)  \
# 0                                                2
# 1                                               28
# 2                                              145
# 3                                              726
# 4                                               23
#
#    Male Risk Dying Percentage  Male Risk Dying Ratio(One in ____ Person)  \
# 0                        19.0                                          5
# 1                         0.8                                        119
# ...

# %%
#Data types
df.dtypes
# Out:
# Cancer Type                                           object
# Male Risk Development Percentage                     float64
# Male Risk Development Ratio(One in ____ Person)        int64
# Male Risk Dying Percentage                           float64
# Male Risk Dying Ratio(One in ____ Person)              int64
# Female Risk Development Percentage                   float64
# Female Risk Development Ratio(One in ____ Person)      int64
# Female Risk Dying Percentage                         float64
# Female Risk Dying Ratio(One in ____ Person)            int64
# dtype: object
